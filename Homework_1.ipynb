# %% [markdown]
# # Homework

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Make a tuple containing natural numbers, the square of which is a multiple of 3, 4, but not a multiple of 8 and not exceeding 12345.

# %%
a = tuple((x for x in range (1, 12345) if ((x**2 % 3 == 0) and (x**2 % 4 == 0) and (x**2 % 8 != 0) and (x**2 <= 12345))))
print(a)
# Out:
# (6, 18, 30, 42, 54, 66, 78, 90, 102)

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Write a function that takes a two-dimensional array and a string as input and returns an array rotated 90 degrees counterclockwise if the string 'left' was passed, and clockwise if the string 'right' was passed.
#
# Example for input: $\begin{bmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ 7 & 8 & 9 \end{bmatrix}$.\
# If the string 'left' is passed, the function should return $\begin{bmatrix} 3 & 6 & 9 \\ 2 & 5 & 8 \\ 1 & 4 & 7 \end{bmatrix}$, and if the string 'right' is passed, the function should return $\begin{bmatrix} 7 & 4 & 1 \\ 8 & 5 & 2 \\ 9 & 6 & 3 \end{bmatrix}$.
#
# Do not use numpy and nested loops. Use list comprehensions and built-in function `zip`.

# %%
def rotation90(matrix, direction='right'):
  if direction == 'right':
    return [list(row)[::-1] for row in zip(*matrix)]
  if direction == 'left':
    return [list(row) for row in zip(*matrix)][::-1]
  else:
    print("Unknown command")

a =[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

print('Original matrix:', a)
print()
print('Right:', rotation90(a,'right'))
print()
print('Left:',rotation90(a,'left'))
# Out:
# Original matrix: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
#
# Right: [[7, 4, 1], [8, 5, 2], [9, 6, 3]]
#
# Left: [[3, 6, 9], [2, 5, 8], [1, 4, 7]]

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Write a function that takes a string as input and returns a dictionary containing the number of occurrences of each character in the string. Use method `count` of strings. Implement this function in one line using $\lambda$-function.
#
# Example for the string 'hello, world!': {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}.

# %%
func = lambda string: {char: string.count(char) for char in string}
print(func('hello, world!'))
# Out:
# {'h': 1, 'e': 1, 'l': 3, 'o': 2, ',': 1, ' ': 1, 'w': 1, 'r': 1, 'd': 1, '!': 1}

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ### Implementing a Library Management System
#
# #### Description
#
# You are required to design and implement a system for managing books and users in a library. The system should allow for the management of books (adding, deleting, searching by various criteria) and users (registration, deletion, searching), as well as tracking the history of interactions between them (issuing and returning books).
#
# #### Tasks
#
# 1. **`Book` Class**:
#    - Attributes: title, author, year of publication, ISBN, number of copies.
#    - Methods: constructor, methods to get information about the book, method to change the number of copies (when issuing and returning books).
#
# 2. **`User` Class**:
#    - Attributes: user name, library card number, list of borrowed books.
#    - Methods: constructor, methods for user registration, methods for adding and removing books from the borrowed list.
#
# 3. **`Library` Class**:
#    - Attributes: list of books, list of users, transaction history (who, when, which book was borrowed and returned).
#    - Methods: constructor, methods for adding and deleting books and users, methods for issuing and returning books, searching for books and users by various criteria, method to display the transaction history.
#
# #### Assignment
#
# 1. Implement the `Book`, `User`, and `Library` classes with the specified attributes and methods.
# 2. Create several books and users, and add them to the library system.
# 3. Implement scenarios for issuing books to users and their return.
# 4. Display the transaction history to show how books were issued and returned.

# %%
class Book:
    def __init__(self, title, author, year, isbn, number):
        self.title = title
        self.author = author
        self.year = year
        self.isbn = isbn
        self.number = number
        print(f"Book {title} created")

    def get_title(self):
        return self.title

    def get_author(self):
        return self.author

    def get_year(self):
        return self.year

    def get_isbn(self):
        return self.isbn

    def get_number(self):
        return self.number

    def change_number(self, status):
        if status == "borrow":
            if self.number > 0:
                self.number -= 1
                return True
            return False

        elif status == "return":
            self.number += 1
            return True

        else:
            raise ValueError("Error - incorrect status")

class User:
    def __init__(self, name, card_number):
        self.name = name
        self.card_number = card_number
        self.borrowed_books = []
        print(f"User {name} created")

    def change_info(self, new_name = None, new_card_number = None):
        if new_name:
            self.name = new_name

        if new_card_number:
            self.card_number = new_card_number

    def borrow_book(self, book):
        if book.get_number() > 0:
            self.borrowed_books.append(book)
            book.change_number("borrow")
            return True
        return False

    def return_book(self, book):
        self.borrowed_books.remove(book)
        book.change_number("return")
        return True

class Library:
    def __init__(self):
        self.users = []
        self.books = []
        self.history = []
        print("Library created")

    def add_user(self, user):
        for lib_user in self.users:
            if lib_user.card_number == user.card_number:
                print("User already exists")
                return False
        self.users.append(user)
        return True

    def remove_user(self, user):
        if user not in self.users:
            print("User not found")
            return False
        if len(user.borrowed_books) > 0:
            print("The user didn't return the books")
            return False
        self.users.remove(user)
        return True

    def add_book(self, book):
        for lib_book in self.books:
            if lib_book.isbn == book.isbn:
                print("Book already exists")
                return False
        self.books.append(book)
        return True

    def remove_book(self, book):
        if book not in self.books:
            print("Book not found")
            return False
        self.books.remove(book)
        return True

    def borrow_book(self, user, book):
        if user.borrow_book(book):
            self.history.append(f"{user.name} borrow {book.title}")
            return True
        return False

    def return_book(self, user, book):
        if book in user.borrowed_books:
            if user.return_book(book):
                self.history.append(f"{user.name} return {book.title}")
                return True
        print("The user didn't borrow the book")
        return False

    def find_book(self, title = None, author = None, year = None, isbn = None):
        result = self.books
        if title:
            result = [book for book in result if title.lower() in book.get_title().lower()]
        if author:
            result = [book for book in result if author.lower() in book.get_author().lower()]
        if year:
            result = [book for book in result if year == book.get_year()]
        if isbn:
            result = [book for book in result if isbn == book.get_isbn()]

        print(f"Total books found: {len(result)}")
        for book in result:
            print (f"Title: {book.title}, Author: {book.author}, Year: {book.year}, ISBN: {book.isbn}, Copies: {book.number}")

    def find_user(self, name = None, card_number = None):
        result = self.users
        if name:
            result = [user for user in result if name.lower() in user.name.lower()]
        if card_number:
            result = [user for user in result if card_number == user.card_number]

        print(f"Total users found: {len(result)}")
        for user in result:
            print(f"Name: {user.name}, Card number: {user.card_number}, Borrowed books: {[book.title for book in user.borrowed_books]}")

    def display_history(self):
        for record in self.history:
            print(record)

system = Library()
book1 = Book("Война и мир", "Толстой Л.Н.", 1865, "978-5-4439-0209-8", 1)
system.add_book(book1)

book2 = Book("Преступление и наказание", "Достоевский Ф.М.", 1866, "978-5-19-011197-2", 3)
system.add_book(book2)


user1 = User("Иван Иванов", 403222)
system.add_user(user1)

user2 = User("Кузнецов Алексей", 867687)
system.add_user(user2)


system.borrow_book(user1, book1)

system.find_book(author = "Толстой Л.Н.")
system.find_user(card_number = 403222)

system.return_book(user1, book1)


system.borrow_book(user2, book1)
system.return_book(user2, book1)

system.display_history()
# Out:
# Library created
# Book Война и мир created
# Book Преступление и наказание created
# User Иван Иванов created
# User Кузнецов Алексей created
# Total books found: 1
# Title: Война и мир, Author: Толстой Л.Н., Year: 1865, ISBN: 978-5-4439-0209-8, Copies: 0
# Total users found: 1
# Name: Иван Иванов, Card number: 403222, Borrowed books: ['Война и мир']
# Иван Иванов borrow Война и мир
# Иван Иванов return Война и мир
# Кузнецов Алексей borrow Война и мир
# Кузнецов Алексей return Война и мир

# %% [markdown]
# ## Problem 5*

# %% [markdown]
# Explain why list `b` changes after the execution of the following code:
#
# ```python
# a = [1, 2, 3]
# b = a
# a[0] = 4
# print(b)
# ```

# %%
a = [1, 2, 3]
b = a
a[0] = 4
print(b)
# Out:
# [4, 2, 3]

# %% [markdown]
# Переменная хранит ссылку на объект, т.е. после операции "b = a" в b храниться ссылка на список, как и в a, и именно поэтому после операции "a[0] = 4" изменился и b.

# %% [markdown]
# ## Problem 6*

# %% [markdown]
# Let
# $$A = \sum_{i=1}^{10000} \frac{1}{i^2},\quad B=\sum_{i=10000}^{1} \frac{1}{i^2}.$$
# Calculate the values of $A$ and $B$ and compare them. What do you observe? Explain why this happens. What is the best way to calculate the value of $\sum\limits_{i=1}^{10000} \dfrac{1}{i^2}$?

# %%
A = 0.0
B = 0.0
for i in range(1,10001):
  A += 1 / (i**2)


for i in range(10000,0,-1):
  B += 1 / (i**2)

print(A)
print(B)

if A < B:
  print("A is lesser than B")
elif A > B:
  print("B is lesser than A")
else:
  print("Numbers are equal")
# Out:
# 1.6448340718480652
# 1.6448340718480596
# B is lesser than A

# %% [markdown]
# Получилось, что A и B не равны. В случае A с некоторого i слагаемые не влияют на сумму из-за округления, так как они слишком малы относительно уже накопленной суммы. В случае B суммирование начинается с меньших слагаемых и поэтому они лучше учитываются при подсчёте, и, следовательно, способ с обратным суммированием дает более точный результат.
